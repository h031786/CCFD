# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np # for numerical purpose 
import pandas as pd  # for creating/reading file
import matplotlib.pyplot as plt # for data visualization
import seaborn as sns  # also for data visualization
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score , precision_score , confusion_matrix , classification_report  # evaluation of model 
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler  # preprocessing technique in scikit-learn used for standardizing features by removing the mean and scaling to unit variance

# %% [markdown]
# ### Converting the dataset to DataFrame

# %%
credit_card_data = pd.read_csv('creditcard.csv')

# %% [markdown]
# ### Printing the first five rows of the dataset

# %%
print('THE FIRST FIVE ROWS-')
credit_card_data.head()
# Out:
# THE FIRST FIVE ROWS-
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# ### Printing the last five rows of the dataset

# %%
print('THE LAST FIVE ROWS-')
credit_card_data.tail()
# Out:
# THE LAST FIVE ROWS-
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %% [markdown]
# ### Printing the  dataset information

# %%
print('DATASET INFORMATION')
credit_card_data.info()
# Out:
# DATASET INFORMATION
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
# ...

# %% [markdown]
# ### Checking the number of missing values in each column

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ### Visualization of the dataset

# %%
print('COUNT-PLOT FOR LEGIT AND FRAUD TRANSACTIONS-')

sns.countplot(x='Class',data=credit_card_data)
# Out:
# COUNT-PLOT FOR LEGIT AND FRAUD TRANSACTIONS-
# <Axes: xlabel='Class', ylabel='count'>

# %% [markdown]
# ### Distribution of legitimate transactions and fraudulent transactions

# %%
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# ### Separating the data for analysis
#
# ## Class 0 indicates transaction is legitimate
# ## Class 1 indicates transaction is fraudulent

# %%
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print('SHAPE OF LEGIT AND FRAUD-')
print(legit.shape)
print(fraud.shape)
# Out:
# SHAPE OF LEGIT AND FRAUD-
# (284315, 31)
# (492, 31)

# %% [markdown]
# ### Printing the description of amount on the basis of legitimate and fraudulent transactions

# %%
print('DESCRIPTION OF AMOUNT ON BASIS OF LEGIT TRANSACTION-')
legit.Amount.describe()
# Out:
# DESCRIPTION OF AMOUNT ON BASIS OF LEGIT TRANSACTION-
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
print('DESCRIPTION OF AMOUNT ON BASIS OF FRAUD TRANSACTION-')
fraud.Amount.describe()
# Out:
# DESCRIPTION OF AMOUNT ON BASIS OF FRAUD TRANSACTION-
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [markdown]
# ### Comparing the values for both the transactions

# %%
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# ### Handling the Imbalance-Dataset

# %%
legit_sample = legit.sample(n=492)

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %% [markdown]
# ### Visualization of the new balanced dataset

# %%
print('COUNT-PLOT FOR NEW DATASET-')
sns.countplot(x='Class',data=new_dataset)
# Out:
# COUNT-PLOT FOR NEW DATASET-
# <Axes: xlabel='Class', ylabel='count'>

# %% [markdown]
# ### Printing first five rows of new balanced dataset

# %%
print(' FIRST FIVE ROWS OF NEW DATASET-')
new_dataset.head()
# Out:
#  FIRST FIVE ROWS OF NEW DATASET-
#             Time        V1        V2        V3        V4        V5        V6  \
# 125312   77613.0  1.192901  0.143424  0.594601  1.056362 -0.425928 -0.249381
# 29954    35712.0  1.178163 -0.018197  0.322896  0.808135 -0.334448 -0.323916
# 205435  135745.0  2.006646  0.466088 -1.408981  1.443767  0.230402 -1.908144
# 197253  131922.0  2.030097  0.374575 -2.371247  0.780993  0.796947 -0.865259
# 158562  111457.0  1.771241 -0.645919 -0.123945  0.293458 -0.030775  1.684953
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 125312 -0.272006  0.130513  0.091339  ... -0.063601 -0.262812 -0.002957
# 29954  -0.025595 -0.008392  0.480869  ... -0.131022 -0.198001 -0.030458
# 205435  0.879571 -0.612610 -0.330093  ...  0.192076  0.719115  0.096113
# 197253  0.247677 -0.265192  0.556488  ... -0.012039  0.312222 -0.034116
# 158562 -1.210181  0.532045  2.601820  ...  0.032624  0.543062  0.244233
#
# ...

# %% [markdown]
# ### Printing last five rows of new balanced dataset

# %%
print('LAST FIVE ROWS OF NEW DATASET-')
new_dataset.tail()
# Out:
# LAST FIVE ROWS OF NEW DATASET-
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %% [markdown]
# ### Distribution of legitimate and fraudlent transactions in new balanced dataset

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %% [markdown]
# ### Comparing the values for both the transactions  in new balanced dataset

# %%
new_dataset.groupby('Class').mean()
# Out:
#                 Time        V1        V2        V3        V4        V5  \
# Class
# 0      100673.447154  0.105590  0.049844 -0.099668 -0.037459  0.031213
# 1       80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.087018 -0.072707  0.024523 -0.007227  ... -0.064929  0.003322
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.067588  0.018198  0.017542 -0.012787 -0.031036 -0.000247  0.015830
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       67.970305
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# ### Printing the correlation matrix

# %%
print('CORRELATION MATRIX-')
corrmat = new_dataset.corr()
fig = plt.figure(figsize = (12, 9))
sns.heatmap(corrmat, vmax = .8, square = True)
plt.show()
# Out:
# CORRELATION MATRIX-

# %% [markdown]
# ### Separating the features and labels (inputs and output)

# %%
X = new_dataset.drop(columns='Class', axis=1) # featues (input)
Y = new_dataset['Class'] # label(output)

# %% [markdown]
# ### Printing of features(input)

# %%
print('FEATURES-',X)
# Out:
# FEATURES-             Time        V1        V2        V3        V4        V5        V6  \
# 125312   77613.0  1.192901  0.143424  0.594601  1.056362 -0.425928 -0.249381
# 29954    35712.0  1.178163 -0.018197  0.322896  0.808135 -0.334448 -0.323916
# 205435  135745.0  2.006646  0.466088 -1.408981  1.443767  0.230402 -1.908144
# 197253  131922.0  2.030097  0.374575 -2.371247  0.780993  0.796947 -0.865259
# 158562  111457.0  1.771241 -0.645919 -0.123945  0.293458 -0.030775  1.684953
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %% [markdown]
# ### Printing of labels(output)

# %%
print('LABELS-',Y)
# Out:
# LABELS- 125312    0
# 29954     0
# 205435    0
# 197253    0
# 158562    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %% [markdown]
# ### Splitting the new balanced dataset into training and testing data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)
scaler=StandardScaler()
x_train=scaler.fit_transform(X_train)
x_test=scaler.fit_transform(X_test)

# %% [markdown]
# ### Printing rows and columns of features(input)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %% [markdown]
# ### Training the Logistic Regression model with training data

# %%
model = LogisticRegression(max_iter=10000)
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %% [markdown]
# ### Calculating the accuracy of training data

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9504447268106735

# %% [markdown]
# ### Calculating the accuracy of testing data

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.934010152284264

# %% [markdown]
# ### Calculating the precision

# %%
prec= precision_score(X_test_prediction, Y_test)
print("The precision is {}".format(prec))
# Out:
# The precision is 0.8877551020408163

# %% [markdown]
# ### Classification Report

# %%
class_reports=classification_report(Y_test,X_test_prediction)
print("CLASS REPORT IS ",class_reports)
# Out:
# CLASS REPORT IS                precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94        99
#            1       0.98      0.89      0.93        98
#
#     accuracy                           0.93       197
#    macro avg       0.94      0.93      0.93       197
# weighted avg       0.94      0.93      0.93       197

# %% [markdown]
# ### Printing the confusion matrix
#
# ## TP- True Positive
# ## TN- True Negative
# ## FP- False Positive
# ## FN- False Negative

# %%
LABELS = ['Legit', 'Fraud']
conf_matrix = confusion_matrix(Y_test, X_test_prediction)
plt.figure(figsize =(12, 12))
sns.heatmap(conf_matrix, xticklabels = LABELS, 
            yticklabels = LABELS, annot = True, fmt ="d")
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %% [markdown]
# ### Collecting user input and predicting whether a fraudulent transaction or legitimate transaction

# %%
# Function to collect user input
def collect_transaction_data():
    transaction_data = {}
    for column in X.columns:
        transaction_data[column] = float(input(f"Enter value for {column}: "))
    return transaction_data

# Function to predict fraud
def predict_fraud(transaction_data, model):
    transaction_df = pd.DataFrame([transaction_data])
    prediction = model.predict(transaction_df)
    return "Fraudulent" if prediction[0] == 1 else "Legitimate"

#For Example
transaction_data = collect_transaction_data()
fraud_prediction = predict_fraud(transaction_data, model)
print('DETAILS OF TRANSACTION-',transaction_data)
print(f"This transaction is potentially {fraud_prediction}.")
# Out:
# DETAILS OF TRANSACTION- {'Time': 1.0, 'V1': 1.1, 'V2': 1.2, 'V3': 1.3, 'V4': 1.4, 'V5': 1.5, 'V6': 1.6, 'V7': -1.1, 'V8': -0.4, 'V9': -0.9, 'V10': -0.006, 'V11': 2.8, 'V12': 2.3, 'V13': 2.8, 'V14': -2.1, 'V15': 1.1, 'V16': 1.1, 'V17': 1.1, 'V18': 1.1, 'V19': 1.1, 'V20': 1.3, 'V21': 1.4, 'V22': 1.5, 'V23': 1.4, 'V24': 1.6, 'V25': 1.3, 'V26': 1.7, 'V27': 1.3, 'V28': -0.06, 'Amount': 1234.0}
# This transaction is potentially Fraudulent.
